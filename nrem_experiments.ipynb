# %%
import numpy as np 
from model import load_dataset, SynapticDownscalingModel, train_model, plot_accuracies, test_model
import matplotlib.pyplot as plt

# %%
train_dataset = load_dataset(train=True)
test_dataset = load_dataset(train=False)
num_epochs = 10

# %%
base_model = SynapticDownscalingModel()

# %%
train_accuracies, test_accuracies, train_losses, per_task_test_accuracies = train_model(base_model, train_dataset, test_dataset, epochs_per_task=num_epochs, nrem_replay=True)
# Out:
# === Training on task 1/5 ===
# Epoch 1/10
#   Train Acc: 0.8286 | Test Acc (Overall): 0.8785
#   Per Task: [0.8785, 0.0, 0.0, 0.0, 0.0]
# Epoch 2/10
#   Train Acc: 0.8976 | Test Acc (Overall): 0.9170
#   Per Task: [0.917, 0.0, 0.0, 0.0, 0.0]
# Epoch 3/10
#   Train Acc: 0.9228 | Test Acc (Overall): 0.9270
#   Per Task: [0.927, 0.0, 0.0, 0.0, 0.0]
# Epoch 4/10
#   Train Acc: 0.9365 | Test Acc (Overall): 0.9355
#   Per Task: [0.9355, 0.0, 0.0, 0.0, 0.0]
# Epoch 5/10
#   Train Acc: 0.9474 | Test Acc (Overall): 0.9405
#   Per Task: [0.9405, 0.0, 0.0, 0.0, 0.0]
# Epoch 6/10
#   Train Acc: 0.9568 | Test Acc (Overall): 0.9425
#   Per Task: [0.9425, 0.0, 0.0, 0.0, 0.0]
# Epoch 7/10
#   Train Acc: 0.9559 | Test Acc (Overall): 0.9385
#   Per Task: [0.9385, 0.0, 0.0, 0.0, 0.0]
# Epoch 8/10
#   Train Acc: 0.9656 | Test Acc (Overall): 0.9440
#   Per Task: [0.944, 0.0, 0.0, 0.0, 0.0]
# Epoch 9/10
#   Train Acc: 0.9680 | Test Acc (Overall): 0.9415
#   Per Task: [0.9415, 0.0, 0.0, 0.0, 0.0]
# Epoch 10/10
#   Train Acc: 0.9768 | Test Acc (Overall): 0.9450
#   Per Task: [0.945, 0.0, 0.0, 0.0, 0.0]
#
# [Consolidating] Storing memories from Task 0...
#    [Buffer] Added 250 samples for Class 0
#    [Buffer] Added 250 samples for Class 1
#
# === Training on task 2/5 ===
# Epoch 1/10
#   Train Acc: 0.1963 | Test Acc (Overall): 0.5395
#   Per Task: [0.913, 0.166, 0.0, 0.0, 0.0]
# Epoch 2/10
#   Train Acc: 0.4393 | Test Acc (Overall): 0.5735
#   Per Task: [0.92, 0.227, 0.0, 0.0, 0.0]
# Epoch 3/10
#   Train Acc: 0.5043 | Test Acc (Overall): 0.7060
#   Per Task: [0.9115, 0.5005, 0.0, 0.0, 0.0]
# Epoch 4/10
#   Train Acc: 0.5721 | Test Acc (Overall): 0.7355
#   Per Task: [0.9065, 0.5645, 0.0, 0.0, 0.0]
# Epoch 5/10
#   Train Acc: 0.6232 | Test Acc (Overall): 0.7612
#   Per Task: [0.8865, 0.636, 0.0, 0.0, 0.0]
# Epoch 6/10
#   Train Acc: 0.6669 | Test Acc (Overall): 0.7668
#   Per Task: [0.9015, 0.632, 0.0, 0.0, 0.0]
# Epoch 7/10
#   Train Acc: 0.7020 | Test Acc (Overall): 0.7660
#   Per Task: [0.8845, 0.6475, 0.0, 0.0, 0.0]
# Epoch 8/10
#   Train Acc: 0.7262 | Test Acc (Overall): 0.7860
#   Per Task: [0.8435, 0.7285, 0.0, 0.0, 0.0]
# Epoch 9/10
#   Train Acc: 0.7457 | Test Acc (Overall): 0.7920
#   Per Task: [0.84, 0.744, 0.0, 0.0, 0.0]
# Epoch 10/10
#   Train Acc: 0.7671 | Test Acc (Overall): 0.7840
#   Per Task: [0.834, 0.734, 0.0, 0.0, 0.0]
#
# [Consolidating] Storing memories from Task 1...
#    [Buffer] Added 250 samples for Class 2
#    [Buffer] Added 250 samples for Class 3
#
# === Training on task 3/5 ===
# Epoch 1/10
#   Train Acc: 0.0311 | Test Acc (Overall): 0.5270
#   Per Task: [0.8575, 0.6665, 0.057, 0.0, 0.0]
# Epoch 2/10
#   Train Acc: 0.1687 | Test Acc (Overall): 0.5730
#   Per Task: [0.8645, 0.641, 0.2135, 0.0, 0.0]
# Epoch 3/10
#   Train Acc: 0.2787 | Test Acc (Overall): 0.6043
#   Per Task: [0.852, 0.6255, 0.3355, 0.0, 0.0]
# Epoch 4/10
#   Train Acc: 0.3872 | Test Acc (Overall): 0.6138
#   Per Task: [0.8505, 0.578, 0.413, 0.0, 0.0]
# Epoch 5/10
#   Train Acc: 0.4754 | Test Acc (Overall): 0.6127
#   Per Task: [0.8355, 0.6165, 0.386, 0.0, 0.0]
# Epoch 6/10
#   Train Acc: 0.5457 | Test Acc (Overall): 0.6388
#   Per Task: [0.8535, 0.496, 0.567, 0.0, 0.0]
# Epoch 7/10
#   Train Acc: 0.6242 | Test Acc (Overall): 0.6278
#   Per Task: [0.823, 0.5535, 0.507, 0.0, 0.0]
# Epoch 8/10
#   Train Acc: 0.6700 | Test Acc (Overall): 0.6413
#   Per Task: [0.8555, 0.4495, 0.619, 0.0, 0.0]
# Epoch 9/10
#   Train Acc: 0.7245 | Test Acc (Overall): 0.6302
#   Per Task: [0.827, 0.349, 0.7145, 0.0, 0.0]
# Epoch 10/10
#   Train Acc: 0.7664 | Test Acc (Overall): 0.6405
#   Per Task: [0.831, 0.396, 0.6945, 0.0, 0.0]
#
# [Consolidating] Storing memories from Task 2...
#    [Buffer] Added 250 samples for Class 4
#    [Buffer] Added 250 samples for Class 5
#
# === Training on task 4/5 ===
# Epoch 1/10
#   Train Acc: 0.2034 | Test Acc (Overall): 0.5593
#   Per Task: [0.8465, 0.428, 0.587, 0.3755, 0.0]
# Epoch 2/10
#   Train Acc: 0.5157 | Test Acc (Overall): 0.5853
#   Per Task: [0.8395, 0.3845, 0.633, 0.484, 0.0]
# Epoch 3/10
#   Train Acc: 0.6193 | Test Acc (Overall): 0.6056
#   Per Task: [0.839, 0.4015, 0.5465, 0.6355, 0.0]
# Epoch 4/10
#   Train Acc: 0.6742 | Test Acc (Overall): 0.6134
#   Per Task: [0.827, 0.41, 0.548, 0.6685, 0.0]
# Epoch 5/10
#   Train Acc: 0.7352 | Test Acc (Overall): 0.6176
#   Per Task: [0.82, 0.3515, 0.6155, 0.6835, 0.0]
# Epoch 6/10
#   Train Acc: 0.7712 | Test Acc (Overall): 0.6186
#   Per Task: [0.8095, 0.3415, 0.558, 0.7655, 0.0]
# Epoch 7/10
#   Train Acc: 0.8085 | Test Acc (Overall): 0.6096
#   Per Task: [0.8145, 0.3515, 0.4755, 0.797, 0.0]
# Epoch 8/10
#   Train Acc: 0.8379 | Test Acc (Overall): 0.6165
#   Per Task: [0.804, 0.3545, 0.538, 0.7695, 0.0]
# Epoch 9/10
#   Train Acc: 0.8645 | Test Acc (Overall): 0.6019
#   Per Task: [0.7765, 0.302, 0.499, 0.83, 0.0]
# Epoch 10/10
#   Train Acc: 0.8828 | Test Acc (Overall): 0.6086
#   Per Task: [0.787, 0.29, 0.5415, 0.816, 0.0]
#
# [Consolidating] Storing memories from Task 3...
#    [Buffer] Added 250 samples for Class 6
#    [Buffer] Added 250 samples for Class 7
#
# === Training on task 5/5 ===
# Epoch 1/10
#   Train Acc: 0.3583 | Test Acc (Overall): 0.5653
#   Per Task: [0.5685, 0.3055, 0.5505, 0.781, 0.621]
# Epoch 2/10
#   Train Acc: 0.6492 | Test Acc (Overall): 0.5842
#   Per Task: [0.605, 0.307, 0.5625, 0.7755, 0.671]
# Epoch 3/10
#   Train Acc: 0.7355 | Test Acc (Overall): 0.5926
#   Per Task: [0.6365, 0.292, 0.5435, 0.7755, 0.7155]
# Epoch 4/10
#   Train Acc: 0.7907 | Test Acc (Overall): 0.5857
#   Per Task: [0.55, 0.3015, 0.55, 0.7785, 0.7485]
# Epoch 5/10
#   Train Acc: 0.8248 | Test Acc (Overall): 0.5896
#   Per Task: [0.547, 0.327, 0.534, 0.7635, 0.7765]
# Epoch 6/10
#   Train Acc: 0.8559 | Test Acc (Overall): 0.5913
#   Per Task: [0.576, 0.3065, 0.5265, 0.755, 0.7925]
# Epoch 7/10
#   Train Acc: 0.8793 | Test Acc (Overall): 0.5829
#   Per Task: [0.474, 0.304, 0.5525, 0.763, 0.821]
# Epoch 8/10
#   Train Acc: 0.8952 | Test Acc (Overall): 0.5820
#   Per Task: [0.4755, 0.296, 0.5495, 0.758, 0.831]
# Epoch 9/10
#   Train Acc: 0.9080 | Test Acc (Overall): 0.5791
#   Per Task: [0.444, 0.3035, 0.549, 0.754, 0.845]
# Epoch 10/10
#   Train Acc: 0.9220 | Test Acc (Overall): 0.5792
#   Per Task: [0.4575, 0.315, 0.5385, 0.7455, 0.8395]
#
# [Consolidating] Storing memories from Task 4...
#    [Buffer] Added 250 samples for Class 8
#    [Buffer] Added 250 samples for Class 9

# %%
task_epochs = num_epochs
epochs = list(range(1, task_epochs*5+1))
plot_accuracies(train_accuracies, test_accuracies, epochs, task_epochs)

# %%
test_model(base_model, test_dataset)
print(len(per_task_test_accuracies))
print(len(per_task_test_accuracies[0]))
# Out:
# Test Accuracy: 0.5792
# 50
# 5

# %%
downscaling_model_p25 = SynapticDownscalingModel()
train_accuracies_p25, test_accuracies_p25, train_losses_p25, per_task_test_accuracies_p25 = train_model(downscaling_model_p25, train_dataset, test_dataset, nrem_replay=True, synaptic_downscaling=True, p=0.25, epochs_per_task=num_epochs)
plot_accuracies(train_accuracies_p25, test_accuracies_p25, epochs, task_epochs)
# Out:
# === Training on task 1/5 ===
# Epoch 1/10
#   Train Acc: 0.8179 | Test Acc (Overall): 0.8915
#   Per Task: [0.8915, 0.0, 0.0, 0.0, 0.0]
# Epoch 2/10
#   Train Acc: 0.8982 | Test Acc (Overall): 0.9160
#   Per Task: [0.916, 0.0, 0.0, 0.0, 0.0]
# Epoch 3/10
#   Train Acc: 0.9218 | Test Acc (Overall): 0.9330
#   Per Task: [0.933, 0.0, 0.0, 0.0, 0.0]
# Epoch 4/10
#   Train Acc: 0.9394 | Test Acc (Overall): 0.9395
#   Per Task: [0.9395, 0.0, 0.0, 0.0, 0.0]
# Epoch 5/10
#   Train Acc: 0.9492 | Test Acc (Overall): 0.9170
#   Per Task: [0.917, 0.0, 0.0, 0.0, 0.0]
# Epoch 6/10
#   Train Acc: 0.9552 | Test Acc (Overall): 0.9320
#   Per Task: [0.932, 0.0, 0.0, 0.0, 0.0]
# Epoch 7/10
#   Train Acc: 0.9611 | Test Acc (Overall): 0.9455
#   Per Task: [0.9455, 0.0, 0.0, 0.0, 0.0]
# Epoch 8/10
#   Train Acc: 0.9693 | Test Acc (Overall): 0.9445
#   Per Task: [0.9445, 0.0, 0.0, 0.0, 0.0]
# Epoch 9/10
#   Train Acc: 0.9710 | Test Acc (Overall): 0.9445
#   Per Task: [0.9445, 0.0, 0.0, 0.0, 0.0]
# Epoch 10/10
#   Train Acc: 0.9735 | Test Acc (Overall): 0.9490
#   Per Task: [0.949, 0.0, 0.0, 0.0, 0.0]
#
# [Consolidating] Storing memories from Task 0...
#    [Buffer] Added 250 samples for Class 0
#    [Buffer] Added 250 samples for Class 1
#
# === Training on task 2/5 ===
# Epoch 1/10
#   Train Acc: 0.2165 | Test Acc (Overall): 0.6430
#   Per Task: [0.913, 0.373, 0.0, 0.0, 0.0]
# Epoch 2/10
#   Train Acc: 0.4678 | Test Acc (Overall): 0.6910
#   Per Task: [0.916, 0.466, 0.0, 0.0, 0.0]
# Epoch 3/10
#   Train Acc: 0.5359 | Test Acc (Overall): 0.7300
#   Per Task: [0.9195, 0.5405, 0.0, 0.0, 0.0]
# Epoch 4/10
#   Train Acc: 0.5881 | Test Acc (Overall): 0.7532
#   Per Task: [0.9075, 0.599, 0.0, 0.0, 0.0]
# Epoch 5/10
#   Train Acc: 0.6412 | Test Acc (Overall): 0.7730
#   Per Task: [0.889, 0.657, 0.0, 0.0, 0.0]
# Epoch 6/10
#   Train Acc: 0.6776 | Test Acc (Overall): 0.7760
#   Per Task: [0.898, 0.654, 0.0, 0.0, 0.0]
# Epoch 7/10
#   Train Acc: 0.7088 | Test Acc (Overall): 0.7877
#   Per Task: [0.8685, 0.707, 0.0, 0.0, 0.0]
# Epoch 8/10
#   Train Acc: 0.7373 | Test Acc (Overall): 0.7900
#   Per Task: [0.844, 0.736, 0.0, 0.0, 0.0]
# Epoch 9/10
#   Train Acc: 0.7506 | Test Acc (Overall): 0.7880
#   Per Task: [0.8525, 0.7235, 0.0, 0.0, 0.0]
# Epoch 10/10
#   Train Acc: 0.7672 | Test Acc (Overall): 0.7930
#   Per Task: [0.85, 0.736, 0.0, 0.0, 0.0]
#
# [Consolidating] Storing memories from Task 1...
#    [Buffer] Added 250 samples for Class 2
#    [Buffer] Added 250 samples for Class 3
#
# === Training on task 3/5 ===
# Epoch 1/10
#   Train Acc: 0.0475 | Test Acc (Overall): 0.5573
#   Per Task: [0.8705, 0.65, 0.1515, 0.0, 0.0]
# Epoch 2/10
#   Train Acc: 0.2403 | Test Acc (Overall): 0.6203
#   Per Task: [0.8665, 0.567, 0.4275, 0.0, 0.0]
# Epoch 3/10
#   Train Acc: 0.3810 | Test Acc (Overall): 0.6277
#   Per Task: [0.8635, 0.568, 0.4515, 0.0, 0.0]
# Epoch 4/10
#   Train Acc: 0.4635 | Test Acc (Overall): 0.6315
#   Per Task: [0.847, 0.56, 0.4875, 0.0, 0.0]
# Epoch 5/10
#   Train Acc: 0.5430 | Test Acc (Overall): 0.6425
#   Per Task: [0.851, 0.4835, 0.593, 0.0, 0.0]
# Epoch 6/10
#   Train Acc: 0.6046 | Test Acc (Overall): 0.6462
#   Per Task: [0.8435, 0.4825, 0.6125, 0.0, 0.0]
# Epoch 7/10
#   Train Acc: 0.6602 | Test Acc (Overall): 0.6420
#   Per Task: [0.827, 0.499, 0.6, 0.0, 0.0]
# Epoch 8/10
#   Train Acc: 0.7133 | Test Acc (Overall): 0.6433
#   Per Task: [0.8315, 0.4495, 0.649, 0.0, 0.0]
# Epoch 9/10
#   Train Acc: 0.7489 | Test Acc (Overall): 0.6473
#   Per Task: [0.839, 0.42, 0.683, 0.0, 0.0]
# Epoch 10/10
#   Train Acc: 0.7858 | Test Acc (Overall): 0.6418
#   Per Task: [0.8555, 0.334, 0.736, 0.0, 0.0]
#
# [Consolidating] Storing memories from Task 2...
#    [Buffer] Added 250 samples for Class 4
#    [Buffer] Added 250 samples for Class 5
#
# === Training on task 4/5 ===
# Epoch 1/10
#   Train Acc: 0.2802 | Test Acc (Overall): 0.5893
#   Per Task: [0.8565, 0.3385, 0.553, 0.609, 0.0]
# Epoch 2/10
#   Train Acc: 0.6045 | Test Acc (Overall): 0.6036
#   Per Task: [0.8555, 0.353, 0.5675, 0.6385, 0.0]
# Epoch 3/10
#   Train Acc: 0.6860 | Test Acc (Overall): 0.5989
#   Per Task: [0.837, 0.317, 0.664, 0.5775, 0.0]
# Epoch 4/10
#   Train Acc: 0.7311 | Test Acc (Overall): 0.6168
#   Per Task: [0.838, 0.33, 0.5515, 0.7475, 0.0]
# Epoch 5/10
#   Train Acc: 0.7804 | Test Acc (Overall): 0.6179
#   Per Task: [0.836, 0.326, 0.554, 0.7555, 0.0]
# Epoch 6/10
#   Train Acc: 0.8066 | Test Acc (Overall): 0.6149
#   Per Task: [0.826, 0.286, 0.5465, 0.801, 0.0]
# Epoch 7/10
#   Train Acc: 0.8413 | Test Acc (Overall): 0.6148
#   Per Task: [0.8145, 0.3005, 0.5385, 0.8055, 0.0]
# Epoch 8/10
#   Train Acc: 0.8624 | Test Acc (Overall): 0.6061
#   Per Task: [0.816, 0.269, 0.4835, 0.856, 0.0]
# Epoch 9/10
#   Train Acc: 0.8847 | Test Acc (Overall): 0.6130
#   Per Task: [0.812, 0.2885, 0.5205, 0.831, 0.0]
# Epoch 10/10
#   Train Acc: 0.8991 | Test Acc (Overall): 0.6044
#   Per Task: [0.8115, 0.293, 0.4525, 0.8605, 0.0]
#
# [Consolidating] Storing memories from Task 3...
#    [Buffer] Added 250 samples for Class 6
#    [Buffer] Added 250 samples for Class 7
#
# === Training on task 5/5 ===
# Epoch 1/10
#   Train Acc: 0.4176 | Test Acc (Overall): 0.5758
#   Per Task: [0.7245, 0.3145, 0.4385, 0.802, 0.5995]
# Epoch 2/10
#   Train Acc: 0.7038 | Test Acc (Overall): 0.5940
#   Per Task: [0.6655, 0.323, 0.454, 0.8095, 0.718]
# Epoch 3/10
#   Train Acc: 0.7842 | Test Acc (Overall): 0.5940
#   Per Task: [0.6405, 0.3105, 0.462, 0.8065, 0.7505]
# Epoch 4/10
#   Train Acc: 0.8283 | Test Acc (Overall): 0.5923
#   Per Task: [0.577, 0.292, 0.4735, 0.81, 0.809]
# Epoch 5/10
#   Train Acc: 0.8614 | Test Acc (Overall): 0.5902
#   Per Task: [0.6205, 0.322, 0.4295, 0.802, 0.777]
# Epoch 6/10
#   Train Acc: 0.8815 | Test Acc (Overall): 0.5912
#   Per Task: [0.6065, 0.3045, 0.4665, 0.8015, 0.777]
# Epoch 7/10
#   Train Acc: 0.8946 | Test Acc (Overall): 0.5891
#   Per Task: [0.54, 0.2955, 0.4795, 0.804, 0.8265]
# Epoch 8/10
#   Train Acc: 0.9114 | Test Acc (Overall): 0.5876
#   Per Task: [0.52, 0.2905, 0.4775, 0.8095, 0.8405]
# Epoch 9/10
#   Train Acc: 0.9262 | Test Acc (Overall): 0.5886
#   Per Task: [0.571, 0.3275, 0.444, 0.783, 0.8175]
# Epoch 10/10
#   Train Acc: 0.9361 | Test Acc (Overall): 0.5806
#   Per Task: [0.5035, 0.3015, 0.461, 0.787, 0.85]
#
# [Consolidating] Storing memories from Task 4...
#    [Buffer] Added 250 samples for Class 8
#    [Buffer] Added 250 samples for Class 9

# %%
downscaling_model_p50 = SynapticDownscalingModel()
train_accuracies_p50, test_accuracies_p50, train_losses_p50, per_task_test_accuracies_p50 = train_model(downscaling_model_p50, train_dataset, test_dataset, nrem_replay=True, synaptic_downscaling=True, p=0.5, epochs_per_task=num_epochs)
plot_accuracies(train_accuracies_p50, test_accuracies_p50, epochs, task_epochs)
# Out:
# === Training on task 1/5 ===
# Epoch 1/10
#   Train Acc: 0.8221 | Test Acc (Overall): 0.8905
#   Per Task: [0.8905, 0.0, 0.0, 0.0, 0.0]
# Epoch 2/10
#   Train Acc: 0.8905 | Test Acc (Overall): 0.9095
#   Per Task: [0.9095, 0.0, 0.0, 0.0, 0.0]
# Epoch 3/10
#   Train Acc: 0.9190 | Test Acc (Overall): 0.9330
#   Per Task: [0.933, 0.0, 0.0, 0.0, 0.0]
# Epoch 4/10
#   Train Acc: 0.9326 | Test Acc (Overall): 0.9355
#   Per Task: [0.9355, 0.0, 0.0, 0.0, 0.0]
# Epoch 5/10
#   Train Acc: 0.9418 | Test Acc (Overall): 0.9375
#   Per Task: [0.9375, 0.0, 0.0, 0.0, 0.0]
# Epoch 6/10
#   Train Acc: 0.9486 | Test Acc (Overall): 0.9470
#   Per Task: [0.947, 0.0, 0.0, 0.0, 0.0]
# Epoch 7/10
#   Train Acc: 0.9560 | Test Acc (Overall): 0.9400
#   Per Task: [0.94, 0.0, 0.0, 0.0, 0.0]
# Epoch 8/10
#   Train Acc: 0.9654 | Test Acc (Overall): 0.9465
#   Per Task: [0.9465, 0.0, 0.0, 0.0, 0.0]
# Epoch 9/10
#   Train Acc: 0.9682 | Test Acc (Overall): 0.9405
#   Per Task: [0.9405, 0.0, 0.0, 0.0, 0.0]
# Epoch 10/10
#   Train Acc: 0.9721 | Test Acc (Overall): 0.9455
#   Per Task: [0.9455, 0.0, 0.0, 0.0, 0.0]
#
# [Consolidating] Storing memories from Task 0...
#    [Buffer] Added 250 samples for Class 0
#    [Buffer] Added 250 samples for Class 1
#
# === Training on task 2/5 ===
# Epoch 1/10
#   Train Acc: 0.2025 | Test Acc (Overall): 0.5685
#   Per Task: [0.9235, 0.2135, 0.0, 0.0, 0.0]
# Epoch 2/10
#   Train Acc: 0.4232 | Test Acc (Overall): 0.6518
#   Per Task: [0.9275, 0.376, 0.0, 0.0, 0.0]
# Epoch 3/10
#   Train Acc: 0.5138 | Test Acc (Overall): 0.7525
#   Per Task: [0.8765, 0.6285, 0.0, 0.0, 0.0]
# Epoch 4/10
#   Train Acc: 0.5680 | Test Acc (Overall): 0.7465
#   Per Task: [0.887, 0.606, 0.0, 0.0, 0.0]
# Epoch 5/10
#   Train Acc: 0.6146 | Test Acc (Overall): 0.7678
#   Per Task: [0.886, 0.6495, 0.0, 0.0, 0.0]
# Epoch 6/10
#   Train Acc: 0.6492 | Test Acc (Overall): 0.7778
#   Per Task: [0.8735, 0.682, 0.0, 0.0, 0.0]
# Epoch 7/10
#   Train Acc: 0.6980 | Test Acc (Overall): 0.7758
#   Per Task: [0.87, 0.6815, 0.0, 0.0, 0.0]
# Epoch 8/10
#   Train Acc: 0.7193 | Test Acc (Overall): 0.7665
#   Per Task: [0.883, 0.65, 0.0, 0.0, 0.0]
# Epoch 9/10
#   Train Acc: 0.7363 | Test Acc (Overall): 0.7778
#   Per Task: [0.8845, 0.671, 0.0, 0.0, 0.0]
# Epoch 10/10
#   Train Acc: 0.7500 | Test Acc (Overall): 0.7820
#   Per Task: [0.864, 0.7, 0.0, 0.0, 0.0]
#
# [Consolidating] Storing memories from Task 1...
#    [Buffer] Added 250 samples for Class 2
#    [Buffer] Added 250 samples for Class 3
#
# === Training on task 3/5 ===
# Epoch 1/10
#   Train Acc: 0.0407 | Test Acc (Overall): 0.5255
#   Per Task: [0.874, 0.638, 0.0645, 0.0, 0.0]
# Epoch 2/10
#   Train Acc: 0.2137 | Test Acc (Overall): 0.5735
#   Per Task: [0.8705, 0.634, 0.216, 0.0, 0.0]
# Epoch 3/10
#   Train Acc: 0.3458 | Test Acc (Overall): 0.5978
#   Per Task: [0.844, 0.5925, 0.357, 0.0, 0.0]
# Epoch 4/10
#   Train Acc: 0.4224 | Test Acc (Overall): 0.6148
#   Per Task: [0.865, 0.5415, 0.438, 0.0, 0.0]
# Epoch 5/10
#   Train Acc: 0.4966 | Test Acc (Overall): 0.6030
#   Per Task: [0.856, 0.6, 0.353, 0.0, 0.0]
# Epoch 6/10
#   Train Acc: 0.5673 | Test Acc (Overall): 0.6347
#   Per Task: [0.8735, 0.422, 0.6085, 0.0, 0.0]
# Epoch 7/10
#   Train Acc: 0.6195 | Test Acc (Overall): 0.6442
#   Per Task: [0.862, 0.4495, 0.621, 0.0, 0.0]
# Epoch 8/10
#   Train Acc: 0.6699 | Test Acc (Overall): 0.6413
#   Per Task: [0.868, 0.3845, 0.6715, 0.0, 0.0]
# Epoch 9/10
#   Train Acc: 0.7092 | Test Acc (Overall): 0.6330
#   Per Task: [0.834, 0.3965, 0.6685, 0.0, 0.0]
# Epoch 10/10
#   Train Acc: 0.7513 | Test Acc (Overall): 0.6368
#   Per Task: [0.8555, 0.322, 0.733, 0.0, 0.0]
#
# [Consolidating] Storing memories from Task 2...
#    [Buffer] Added 250 samples for Class 4
#    [Buffer] Added 250 samples for Class 5
#
# === Training on task 4/5 ===
# Epoch 1/10
#   Train Acc: 0.1657 | Test Acc (Overall): 0.5474
#   Per Task: [0.863, 0.349, 0.587, 0.3905, 0.0]
# Epoch 2/10
#   Train Acc: 0.5019 | Test Acc (Overall): 0.5927
#   Per Task: [0.8565, 0.3485, 0.6, 0.566, 0.0]
# Epoch 3/10
#   Train Acc: 0.6107 | Test Acc (Overall): 0.6078
#   Per Task: [0.839, 0.33, 0.5855, 0.6765, 0.0]
# Epoch 4/10
#   Train Acc: 0.6724 | Test Acc (Overall): 0.6035
#   Per Task: [0.844, 0.311, 0.623, 0.636, 0.0]
# Epoch 5/10
#   Train Acc: 0.7184 | Test Acc (Overall): 0.6114
#   Per Task: [0.835, 0.3175, 0.548, 0.745, 0.0]
# Epoch 6/10
#   Train Acc: 0.7603 | Test Acc (Overall): 0.6145
#   Per Task: [0.839, 0.3035, 0.5765, 0.739, 0.0]
# Epoch 7/10
#   Train Acc: 0.7950 | Test Acc (Overall): 0.6140
#   Per Task: [0.8385, 0.318, 0.5725, 0.727, 0.0]
# Epoch 8/10
#   Train Acc: 0.8290 | Test Acc (Overall): 0.6101
#   Per Task: [0.829, 0.2685, 0.567, 0.776, 0.0]
# Epoch 9/10
#   Train Acc: 0.8609 | Test Acc (Overall): 0.6038
#   Per Task: [0.8405, 0.248, 0.5235, 0.803, 0.0]
# Epoch 10/10
#   Train Acc: 0.8806 | Test Acc (Overall): 0.6015
#   Per Task: [0.818, 0.2365, 0.5305, 0.821, 0.0]
#
# [Consolidating] Storing memories from Task 3...
#    [Buffer] Added 250 samples for Class 6
#    [Buffer] Added 250 samples for Class 7
#
# === Training on task 5/5 ===
# Epoch 1/10
#   Train Acc: 0.4137 | Test Acc (Overall): 0.5750
#   Per Task: [0.713, 0.2975, 0.5225, 0.7595, 0.5825]
# Epoch 2/10
#   Train Acc: 0.6685 | Test Acc (Overall): 0.5838
#   Per Task: [0.667, 0.2825, 0.5485, 0.7945, 0.6265]
# Epoch 3/10
#   Train Acc: 0.7431 | Test Acc (Overall): 0.5864
#   Per Task: [0.608, 0.242, 0.5525, 0.7905, 0.739]
# Epoch 4/10
#   Train Acc: 0.7912 | Test Acc (Overall): 0.5858
#   Per Task: [0.5665, 0.2655, 0.5515, 0.7575, 0.788]
# Epoch 5/10
#   Train Acc: 0.8256 | Test Acc (Overall): 0.5932
#   Per Task: [0.5845, 0.269, 0.5465, 0.793, 0.773]
# Epoch 6/10
#   Train Acc: 0.8495 | Test Acc (Overall): 0.5904
#   Per Task: [0.557, 0.2665, 0.5475, 0.792, 0.789]
# Epoch 7/10
#   Train Acc: 0.8704 | Test Acc (Overall): 0.5883
#   Per Task: [0.528, 0.3015, 0.5295, 0.7625, 0.82]
# Epoch 8/10
#   Train Acc: 0.8864 | Test Acc (Overall): 0.5868
#   Per Task: [0.539, 0.254, 0.554, 0.7695, 0.8175]
# Epoch 9/10
#   Train Acc: 0.9010 | Test Acc (Overall): 0.5864
#   Per Task: [0.522, 0.259, 0.5575, 0.7495, 0.844]
# Epoch 10/10
#   Train Acc: 0.9114 | Test Acc (Overall): 0.5884
#   Per Task: [0.538, 0.2615, 0.543, 0.766, 0.8335]
#
# [Consolidating] Storing memories from Task 4...
#    [Buffer] Added 250 samples for Class 8
#    [Buffer] Added 250 samples for Class 9

# %%
downscaling_model_p75 = SynapticDownscalingModel()
train_accuracies_p75, test_accuracies_p75, train_losses_p75, per_task_test_accuracies_p75 = train_model(downscaling_model_p75, train_dataset, test_dataset, nrem_replay=True, synaptic_downscaling=True, p=0.75, epochs_per_task=num_epochs)
plot_accuracies(train_accuracies_p75, test_accuracies_p75, epochs, task_epochs)
# Out:
# === Training on task 1/5 ===
# Epoch 1/10
#   Train Acc: 0.8220 | Test Acc (Overall): 0.8870
#   Per Task: [0.887, 0.0, 0.0, 0.0, 0.0]
# Epoch 2/10
#   Train Acc: 0.8973 | Test Acc (Overall): 0.9020
#   Per Task: [0.902, 0.0, 0.0, 0.0, 0.0]
# Epoch 3/10
#   Train Acc: 0.9227 | Test Acc (Overall): 0.9250
#   Per Task: [0.925, 0.0, 0.0, 0.0, 0.0]
# Epoch 4/10
#   Train Acc: 0.9352 | Test Acc (Overall): 0.9385
#   Per Task: [0.9385, 0.0, 0.0, 0.0, 0.0]
# Epoch 5/10
#   Train Acc: 0.9462 | Test Acc (Overall): 0.9425
#   Per Task: [0.9425, 0.0, 0.0, 0.0, 0.0]
# Epoch 6/10
#   Train Acc: 0.9527 | Test Acc (Overall): 0.9460
#   Per Task: [0.946, 0.0, 0.0, 0.0, 0.0]
# Epoch 7/10
#   Train Acc: 0.9620 | Test Acc (Overall): 0.9420
#   Per Task: [0.942, 0.0, 0.0, 0.0, 0.0]
# Epoch 8/10
#   Train Acc: 0.9700 | Test Acc (Overall): 0.9475
#   Per Task: [0.9475, 0.0, 0.0, 0.0, 0.0]
# Epoch 9/10
#   Train Acc: 0.9742 | Test Acc (Overall): 0.9465
#   Per Task: [0.9465, 0.0, 0.0, 0.0, 0.0]
# Epoch 10/10
#   Train Acc: 0.9821 | Test Acc (Overall): 0.9465
#   Per Task: [0.9465, 0.0, 0.0, 0.0, 0.0]
#
# [Consolidating] Storing memories from Task 0...
#    [Buffer] Added 250 samples for Class 0
#    [Buffer] Added 250 samples for Class 1
#
# === Training on task 2/5 ===
# Epoch 1/10
#   Train Acc: 0.2088 | Test Acc (Overall): 0.6368
#   Per Task: [0.9095, 0.364, 0.0, 0.0, 0.0]
# Epoch 2/10
#   Train Acc: 0.4292 | Test Acc (Overall): 0.6208
#   Per Task: [0.9195, 0.322, 0.0, 0.0, 0.0]
# Epoch 3/10
#   Train Acc: 0.4977 | Test Acc (Overall): 0.7190
#   Per Task: [0.9065, 0.5315, 0.0, 0.0, 0.0]
# Epoch 4/10
#   Train Acc: 0.5533 | Test Acc (Overall): 0.7362
#   Per Task: [0.9105, 0.562, 0.0, 0.0, 0.0]
# Epoch 5/10
#   Train Acc: 0.6040 | Test Acc (Overall): 0.7395
#   Per Task: [0.9155, 0.5635, 0.0, 0.0, 0.0]
# Epoch 6/10
#   Train Acc: 0.6449 | Test Acc (Overall): 0.7642
#   Per Task: [0.9, 0.6285, 0.0, 0.0, 0.0]
# Epoch 7/10
#   Train Acc: 0.6894 | Test Acc (Overall): 0.7752
#   Per Task: [0.8935, 0.657, 0.0, 0.0, 0.0]
# Epoch 8/10
#   Train Acc: 0.7177 | Test Acc (Overall): 0.7883
#   Per Task: [0.856, 0.7205, 0.0, 0.0, 0.0]
# Epoch 9/10
#   Train Acc: 0.7388 | Test Acc (Overall): 0.7812
#   Per Task: [0.8925, 0.67, 0.0, 0.0, 0.0]
# Epoch 10/10
#   Train Acc: 0.7590 | Test Acc (Overall): 0.7837
#   Per Task: [0.893, 0.6745, 0.0, 0.0, 0.0]
#
# [Consolidating] Storing memories from Task 1...
#    [Buffer] Added 250 samples for Class 2
#    [Buffer] Added 250 samples for Class 3
#
# === Training on task 3/5 ===
# Epoch 1/10
#   Train Acc: 0.0789 | Test Acc (Overall): 0.5757
#   Per Task: [0.8945, 0.522, 0.3105, 0.0, 0.0]
# Epoch 2/10
#   Train Acc: 0.2554 | Test Acc (Overall): 0.5855
#   Per Task: [0.89, 0.5455, 0.321, 0.0, 0.0]
# Epoch 3/10
#   Train Acc: 0.3608 | Test Acc (Overall): 0.6005
#   Per Task: [0.8805, 0.543, 0.378, 0.0, 0.0]
# Epoch 4/10
#   Train Acc: 0.4508 | Test Acc (Overall): 0.6190
#   Per Task: [0.8825, 0.495, 0.4795, 0.0, 0.0]
# Epoch 5/10
#   Train Acc: 0.5315 | Test Acc (Overall): 0.6365
#   Per Task: [0.875, 0.532, 0.5025, 0.0, 0.0]
# Epoch 6/10
#   Train Acc: 0.5955 | Test Acc (Overall): 0.6332
#   Per Task: [0.896, 0.396, 0.6075, 0.0, 0.0]
# Epoch 7/10
#   Train Acc: 0.6586 | Test Acc (Overall): 0.6358
#   Per Task: [0.875, 0.3745, 0.658, 0.0, 0.0]
# Epoch 8/10
#   Train Acc: 0.7118 | Test Acc (Overall): 0.6423
#   Per Task: [0.85, 0.4595, 0.6175, 0.0, 0.0]
# Epoch 9/10
#   Train Acc: 0.7471 | Test Acc (Overall): 0.6373
#   Per Task: [0.881, 0.3645, 0.6665, 0.0, 0.0]
# Epoch 10/10
#   Train Acc: 0.7849 | Test Acc (Overall): 0.6355
#   Per Task: [0.8465, 0.3155, 0.7445, 0.0, 0.0]
#
# [Consolidating] Storing memories from Task 2...
#    [Buffer] Added 250 samples for Class 4
#    [Buffer] Added 250 samples for Class 5
#
# === Training on task 4/5 ===
# Epoch 1/10
#   Train Acc: 0.1875 | Test Acc (Overall): 0.5796
#   Per Task: [0.852, 0.3695, 0.613, 0.484, 0.0]
# Epoch 2/10
#   Train Acc: 0.5414 | Test Acc (Overall): 0.6095
#   Per Task: [0.843, 0.395, 0.545, 0.655, 0.0]
# Epoch 3/10
#   Train Acc: 0.6362 | Test Acc (Overall): 0.6186
#   Per Task: [0.848, 0.3265, 0.536, 0.764, 0.0]
# Epoch 4/10
#   Train Acc: 0.6990 | Test Acc (Overall): 0.6204
#   Per Task: [0.8385, 0.357, 0.5935, 0.6925, 0.0]
# Epoch 5/10
#   Train Acc: 0.7431 | Test Acc (Overall): 0.6216
#   Per Task: [0.8225, 0.314, 0.6055, 0.7445, 0.0]
# Epoch 6/10
#   Train Acc: 0.7819 | Test Acc (Overall): 0.6210
#   Per Task: [0.832, 0.3645, 0.551, 0.7365, 0.0]
# Epoch 7/10
#   Train Acc: 0.8153 | Test Acc (Overall): 0.6184
#   Per Task: [0.8435, 0.2855, 0.543, 0.8015, 0.0]
# Epoch 8/10
#   Train Acc: 0.8353 | Test Acc (Overall): 0.6244
#   Per Task: [0.8375, 0.303, 0.585, 0.772, 0.0]
# Epoch 9/10
#   Train Acc: 0.8657 | Test Acc (Overall): 0.6118
#   Per Task: [0.8395, 0.279, 0.5055, 0.823, 0.0]
# Epoch 10/10
#   Train Acc: 0.8869 | Test Acc (Overall): 0.5951
#   Per Task: [0.7895, 0.23, 0.503, 0.858, 0.0]
#
# [Consolidating] Storing memories from Task 3...
#    [Buffer] Added 250 samples for Class 6
#    [Buffer] Added 250 samples for Class 7
#
# === Training on task 5/5 ===
# Epoch 1/10
#   Train Acc: 0.4019 | Test Acc (Overall): 0.5649
#   Per Task: [0.694, 0.227, 0.5235, 0.8285, 0.5515]
# Epoch 2/10
#   Train Acc: 0.6792 | Test Acc (Overall): 0.5819
#   Per Task: [0.673, 0.2465, 0.5195, 0.8315, 0.639]
# Epoch 3/10
#   Train Acc: 0.7580 | Test Acc (Overall): 0.5901
#   Per Task: [0.6095, 0.266, 0.5225, 0.8165, 0.736]
# Epoch 4/10
#   Train Acc: 0.8106 | Test Acc (Overall): 0.5903
#   Per Task: [0.626, 0.279, 0.4885, 0.7945, 0.7635]
# Epoch 5/10
#   Train Acc: 0.8406 | Test Acc (Overall): 0.5772
#   Per Task: [0.497, 0.2385, 0.518, 0.7955, 0.837]
# Epoch 6/10
#   Train Acc: 0.8703 | Test Acc (Overall): 0.5824
#   Per Task: [0.502, 0.268, 0.518, 0.8025, 0.8215]
# Epoch 7/10
#   Train Acc: 0.8877 | Test Acc (Overall): 0.5789
#   Per Task: [0.4765, 0.2545, 0.532, 0.796, 0.8355]
# Epoch 8/10
#   Train Acc: 0.9013 | Test Acc (Overall): 0.5857
#   Per Task: [0.5245, 0.2545, 0.5185, 0.798, 0.833]
# Epoch 9/10
#   Train Acc: 0.9104 | Test Acc (Overall): 0.5755
#   Per Task: [0.474, 0.256, 0.4805, 0.807, 0.86]
# Epoch 10/10
#   Train Acc: 0.9207 | Test Acc (Overall): 0.5801
#   Per Task: [0.5005, 0.2485, 0.507, 0.796, 0.8485]
#
# [Consolidating] Storing memories from Task 4...
#    [Buffer] Added 250 samples for Class 8
#    [Buffer] Added 250 samples for Class 9

# %%
num_tasks = 5
colors = plt.cm.get_cmap('tab10', num_tasks)
task_labels = [f"Task {t}" for t in range(num_tasks)]

#fig, axes = plt.subplots(1, 4, sharey=True)

model_tests = [per_task_test_accuracies,per_task_test_accuracies_p25, per_task_test_accuracies_p50, per_task_test_accuracies_p75]
labels = ['No Downscaling', 'p=0.25', 'p=0.5', 'p=0.75']
for i in range(len(model_tests)):
    task_test_accuracies = [[], [], [], [], []]
    for j in range(num_tasks):
        for k in range(len(model_tests[i])):
            task_test_accuracies[j].append(model_tests[i][k][j]*0.2)
    task_test_accuracies = np.array(task_test_accuracies)
    task_test_accuracies[1][task_epochs:]+=task_test_accuracies[0][task_epochs:]
    task_test_accuracies[2][task_epochs*2:]+=task_test_accuracies[1][task_epochs*2:]
    task_test_accuracies[3][task_epochs*3:]+=task_test_accuracies[2][task_epochs*3:]
    task_test_accuracies[4][task_epochs*4:]+=task_test_accuracies[3][task_epochs*4:]
    #print(task_test_accuracies)
    plt.figure()
    for t in range(num_tasks):
        plt.plot(range(t*task_epochs+1, len(task_test_accuracies[t])+1), task_test_accuracies[t][t*task_epochs:], label=task_labels[t])
        plt.xlabel('Epochs')
        plt.ylim(bottom=0, top=0.8)
        plt.ylabel('Test Accuracy')
        plt.title(labels[i] + ' - Per Task Test Accuracies')
        plt.legend()
    plt.show()
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_22108\1749107197.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap('tab10', num_tasks)
