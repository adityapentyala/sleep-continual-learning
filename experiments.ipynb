# %%
import numpy as np 
from model import load_dataset, SynapticDownscalingModel, train_model, plot_accuracies, test_model
import matplotlib.pyplot as plt

# %%
train_dataset = load_dataset(train=True)
test_dataset = load_dataset(train=False)

# %%
base_model = SynapticDownscalingModel()

# %%
train_accuracies, test_accuracies, train_losses, per_task_test_accuracies = train_model(base_model, train_dataset, test_dataset, epochs_per_task=5, nrem_replay=True)
# Out:
# === Training on task 1/5 ===
# Epoch 1/5
#   Train Acc: 0.8436 | Test Acc (Overall): 0.9100
#   Per Task: [0.91, 0.0, 0.0, 0.0, 0.0]
# Epoch 2/5
#   Train Acc: 0.9210 | Test Acc (Overall): 0.8980
#   Per Task: [0.898, 0.0, 0.0, 0.0, 0.0]
# Epoch 3/5
#   Train Acc: 0.9364 | Test Acc (Overall): 0.9425
#   Per Task: [0.9425, 0.0, 0.0, 0.0, 0.0]
# Epoch 4/5
#   Train Acc: 0.9440 | Test Acc (Overall): 0.9435
#   Per Task: [0.9435, 0.0, 0.0, 0.0, 0.0]
# Epoch 5/5
#   Train Acc: 0.9597 | Test Acc (Overall): 0.9485
#   Per Task: [0.9485, 0.0, 0.0, 0.0, 0.0]
#
# [Consolidating] Storing memories from Task 0...
#    [Buffer] Added 250 samples for Class 0
#    [Buffer] Added 250 samples for Class 1
#
# === Training on task 2/5 ===
# Epoch 1/5
#   Train Acc: 0.1412 | Test Acc (Overall): 0.6458
#   Per Task: [0.902, 0.3895, 0.0, 0.0, 0.0]
# Epoch 2/5
#   Train Acc: 0.3887 | Test Acc (Overall): 0.5262
#   Per Task: [0.8845, 0.168, 0.0, 0.0, 0.0]
# Epoch 3/5
#   Train Acc: 0.5010 | Test Acc (Overall): 0.7258
#   Per Task: [0.8785, 0.573, 0.0, 0.0, 0.0]
# Epoch 4/5
#   Train Acc: 0.5793 | Test Acc (Overall): 0.7035
#   Per Task: [0.9265, 0.4805, 0.0, 0.0, 0.0]
# Epoch 5/5
#   Train Acc: 0.6170 | Test Acc (Overall): 0.7650
#   Per Task: [0.884, 0.646, 0.0, 0.0, 0.0]
#
# [Consolidating] Storing memories from Task 1...
#    [Buffer] Added 250 samples for Class 2
#    [Buffer] Added 250 samples for Class 3
#
# === Training on task 3/5 ===
# Epoch 1/5
#   Train Acc: 0.0473 | Test Acc (Overall): 0.5297
#   Per Task: [0.891, 0.6145, 0.0835, 0.0, 0.0]
# Epoch 2/5
#   Train Acc: 0.2664 | Test Acc (Overall): 0.6023
#   Per Task: [0.8915, 0.4955, 0.42, 0.0, 0.0]
# Epoch 3/5
#   Train Acc: 0.3710 | Test Acc (Overall): 0.6055
#   Per Task: [0.8885, 0.523, 0.405, 0.0, 0.0]
# Epoch 4/5
#   Train Acc: 0.4687 | Test Acc (Overall): 0.6223
#   Per Task: [0.878, 0.3985, 0.5905, 0.0, 0.0]
# Epoch 5/5
#   Train Acc: 0.5442 | Test Acc (Overall): 0.6298
#   Per Task: [0.8825, 0.3685, 0.6385, 0.0, 0.0]
#
# [Consolidating] Storing memories from Task 2...
#    [Buffer] Added 250 samples for Class 4
#    [Buffer] Added 250 samples for Class 5
#
# === Training on task 4/5 ===
# Epoch 1/5
#   Train Acc: 0.2049 | Test Acc (Overall): 0.5677
#   Per Task: [0.875, 0.3655, 0.5395, 0.491, 0.0]
# Epoch 2/5
#   Train Acc: 0.5230 | Test Acc (Overall): 0.5851
#   Per Task: [0.878, 0.3705, 0.5615, 0.5305, 0.0]
# Epoch 3/5
#   Train Acc: 0.6148 | Test Acc (Overall): 0.6001
#   Per Task: [0.8545, 0.3665, 0.552, 0.6275, 0.0]
# Epoch 4/5
#   Train Acc: 0.6797 | Test Acc (Overall): 0.6041
#   Per Task: [0.86, 0.3025, 0.5735, 0.6805, 0.0]
# Epoch 5/5
#   Train Acc: 0.7304 | Test Acc (Overall): 0.6078
#   Per Task: [0.844, 0.3325, 0.524, 0.7305, 0.0]
#
# [Consolidating] Storing memories from Task 3...
#    [Buffer] Added 250 samples for Class 6
#    [Buffer] Added 250 samples for Class 7
#
# === Training on task 5/5 ===
# Epoch 1/5
#   Train Acc: 0.3707 | Test Acc (Overall): 0.5686
#   Per Task: [0.647, 0.374, 0.527, 0.682, 0.613]
# Epoch 2/5
#   Train Acc: 0.6526 | Test Acc (Overall): 0.5811
#   Per Task: [0.688, 0.332, 0.5375, 0.695, 0.653]
# Epoch 3/5
#   Train Acc: 0.7490 | Test Acc (Overall): 0.5903
#   Per Task: [0.6825, 0.362, 0.5205, 0.685, 0.7015]
# Epoch 4/5
#   Train Acc: 0.8071 | Test Acc (Overall): 0.5916
#   Per Task: [0.627, 0.3495, 0.523, 0.696, 0.7625]
# Epoch 5/5
#   Train Acc: 0.8402 | Test Acc (Overall): 0.5885
#   Per Task: [0.57, 0.353, 0.5275, 0.6745, 0.8175]
#
# [Consolidating] Storing memories from Task 4...
#    [Buffer] Added 250 samples for Class 8
#    [Buffer] Added 250 samples for Class 9

# %%
task_epochs = 5
epochs = list(range(1, 5*5+1))
plot_accuracies(train_accuracies, test_accuracies, epochs, task_epochs)

# %%
test_model(base_model, test_dataset)
# Out:
# Test Accuracy: 0.5885
# 0.5885

# %%
downscaling_model_p25 = SynapticDownscalingModel()
train_accuracies_p25, test_accuracies_p25, train_losses_p25, per_task_test_accuracies_p25 = train_model(downscaling_model_p25, train_dataset, test_dataset, nrem_replay=True, synaptic_downscaling=True, p=0.25, epochs_per_task=5)
plot_accuracies(train_accuracies_p25, test_accuracies_p25, epochs, task_epochs)
# Out:
# === Training on task 1/5 ===
# Epoch 1/10
#   Train Acc: 0.8356 | Test Acc (Overall): 0.9125
#   Per Task: [0.9125, 0.0, 0.0, 0.0, 0.0]
# Epoch 2/10
#   Train Acc: 0.9114 | Test Acc (Overall): 0.9230
#   Per Task: [0.923, 0.0, 0.0, 0.0, 0.0]
# Epoch 3/10
#   Train Acc: 0.9347 | Test Acc (Overall): 0.9290
#   Per Task: [0.929, 0.0, 0.0, 0.0, 0.0]
# Epoch 4/10
#   Train Acc: 0.9470 | Test Acc (Overall): 0.9450
#   Per Task: [0.945, 0.0, 0.0, 0.0, 0.0]
# Epoch 5/10
#   Train Acc: 0.9563 | Test Acc (Overall): 0.9520
#   Per Task: [0.952, 0.0, 0.0, 0.0, 0.0]
# Epoch 6/10
#   Train Acc: 0.9670 | Test Acc (Overall): 0.9490
#   Per Task: [0.949, 0.0, 0.0, 0.0, 0.0]
# Epoch 7/10
#   Train Acc: 0.9708 | Test Acc (Overall): 0.9460
#   Per Task: [0.946, 0.0, 0.0, 0.0, 0.0]
# Epoch 8/10
#   Train Acc: 0.9763 | Test Acc (Overall): 0.9425
#   Per Task: [0.9425, 0.0, 0.0, 0.0, 0.0]
# Epoch 9/10
#   Train Acc: 0.9834 | Test Acc (Overall): 0.9390
#   Per Task: [0.939, 0.0, 0.0, 0.0, 0.0]
# Epoch 10/10
#   Train Acc: 0.9873 | Test Acc (Overall): 0.9365
#   Per Task: [0.9365, 0.0, 0.0, 0.0, 0.0]
#
# [Consolidating] Storing memories from Task 0...
#    [Buffer] Added 250 samples for Class 0
#    [Buffer] Added 250 samples for Class 1
#
# === Training on task 2/5 ===
# Epoch 1/10
#   Train Acc: 0.1355 | Test Acc (Overall): 0.6470
#   Per Task: [0.896, 0.398, 0.0, 0.0, 0.0]
# Epoch 2/10
#   Train Acc: 0.4195 | Test Acc (Overall): 0.6360
#   Per Task: [0.9155, 0.3565, 0.0, 0.0, 0.0]
# Epoch 3/10
#   Train Acc: 0.5156 | Test Acc (Overall): 0.7460
#   Per Task: [0.9005, 0.5915, 0.0, 0.0, 0.0]
# Epoch 4/10
#   Train Acc: 0.5876 | Test Acc (Overall): 0.7335
#   Per Task: [0.8915, 0.5755, 0.0, 0.0, 0.0]
# Epoch 5/10
#   Train Acc: 0.6352 | Test Acc (Overall): 0.7375
#   Per Task: [0.8855, 0.5895, 0.0, 0.0, 0.0]
# Epoch 6/10
#   Train Acc: 0.6691 | Test Acc (Overall): 0.7630
#   Per Task: [0.8665, 0.6595, 0.0, 0.0, 0.0]
# Epoch 7/10
#   Train Acc: 0.7070 | Test Acc (Overall): 0.7650
#   Per Task: [0.8725, 0.6575, 0.0, 0.0, 0.0]
# Epoch 8/10
#   Train Acc: 0.7242 | Test Acc (Overall): 0.7790
#   Per Task: [0.8675, 0.6905, 0.0, 0.0, 0.0]
# Epoch 9/10
#   Train Acc: 0.7425 | Test Acc (Overall): 0.7700
#   Per Task: [0.855, 0.685, 0.0, 0.0, 0.0]
# Epoch 10/10
#   Train Acc: 0.7580 | Test Acc (Overall): 0.7732
#   Per Task: [0.8555, 0.691, 0.0, 0.0, 0.0]
#
# [Consolidating] Storing memories from Task 1...
#    [Buffer] Added 250 samples for Class 2
#    [Buffer] Added 250 samples for Class 3
#
# === Training on task 3/5 ===
# Epoch 1/10
#   Train Acc: 0.0069 | Test Acc (Overall): 0.5187
#   Per Task: [0.8795, 0.605, 0.0715, 0.0, 0.0]
# Epoch 2/10
#   Train Acc: 0.1509 | Test Acc (Overall): 0.5663
#   Per Task: [0.8715, 0.609, 0.2185, 0.0, 0.0]
# Epoch 3/10
#   Train Acc: 0.2954 | Test Acc (Overall): 0.5675
#   Per Task: [0.877, 0.5805, 0.245, 0.0, 0.0]
# Epoch 4/10
#   Train Acc: 0.4008 | Test Acc (Overall): 0.6048
#   Per Task: [0.8495, 0.5655, 0.3995, 0.0, 0.0]
# Epoch 5/10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 downscaling_model_p25 = SynapticDownscalingModel()
# ----> 2 train_accuracies_p25, test_accuracies_p25, train_losses_p25, per_task_test_accuracies_p25 = train_model(downscaling_model_p25, train_dataset, test_dataset, nrem_replay=True, synaptic_downscaling=True, p=0.25)
#       3 plot_accuracies(train_accuracies_p25, test_accuracies_p25, epochs)
#
# File c:\Users\adity\OneDrive\Documents\college\4-1\proj\synaptic-downscaling-expt\model.py:228, in train_model(model, train_dataset, test_dataset, epochs_per_task, batch_size, learning_rate, p, synaptic_downscaling, pruning, nrem_replay)
#     225 if task > 0 and nrem_replay==True:
#     226     # noise = torch.randn_like(images)
#     227     teacher.eval()
# --> 228     teacher_outputs = teacher(replay_images)
#     229     model_outputs = model(replay_images)
#     230     distillation_loss = distillation_criterion(model_outputs, teacher_outputs)
#
# File c:\Users\adity\OneDrive\Documents\college\4-1\proj\synaptic-downscaling-expt\env\lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\adity\OneDrive\Documents\college\4-1\proj\synaptic-downscaling-expt\env\lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\adity\OneDrive\Documents\college\4-1\proj\synaptic-downscaling-expt\model.py:47, in SynapticDownscalingModel.forward(self, x)
#      44 out = self.pool1(out)
#      45 assert out.shape[2] == 16 and out.shape[3] == 16, f"Expected spatial dimensions to be 16x16, but got {out.shape[2]}x{out.shape[3]}"
# ---> 47 out = self.conv2(out)
#      48 out = self.relu2(out)
#      49 out = self.pool2(out)
#
# File c:\Users\adity\OneDrive\Documents\college\4-1\proj\synaptic-downscaling-expt\env\lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\adity\OneDrive\Documents\college\4-1\proj\synaptic-downscaling-expt\env\lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\adity\OneDrive\Documents\college\4-1\proj\synaptic-downscaling-expt\env\lib\site-packages\torch\nn\modules\conv.py:548, in Conv2d.forward(self, input)
#     547 def forward(self, input: Tensor) -> Tensor:
# --> 548     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\adity\OneDrive\Documents\college\4-1\proj\synaptic-downscaling-expt\env\lib\site-packages\torch\nn\modules\conv.py:543, in Conv2d._conv_forward(self, input, weight, bias)
#     531 if self.padding_mode != "zeros":
#     532     return F.conv2d(
#     533         F.pad(
#     534             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     541         self.groups,
#     542     )
# --> 543 return F.conv2d(
#     544     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     545 )
#
# KeyboardInterrupt:

# %%
downscaling_model_p50 = SynapticDownscalingModel()
train_accuracies_p50, test_accuracies_p50, train_losses_p50, per_task_test_accuracies_p50 = train_model(downscaling_model_p50, train_dataset, test_dataset, nrem_replay=True, synaptic_downscaling=True, p=0.5, epochs_per_task=5)
plot_accuracies(train_accuracies_p50, test_accuracies_p50, epochs, task_epochs)
# Out:
# === Training on task 1/5 ===
# Epoch 1/10
#   Train Acc: 0.8289 | Test Acc (Overall): 0.9070
#   Per Task: [0.907, 0.0, 0.0, 0.0, 0.0]
# Epoch 2/10
#   Train Acc: 0.9137 | Test Acc (Overall): 0.9265
#   Per Task: [0.9265, 0.0, 0.0, 0.0, 0.0]
# Epoch 3/10
#   Train Acc: 0.9361 | Test Acc (Overall): 0.9380
#   Per Task: [0.938, 0.0, 0.0, 0.0, 0.0]
# Epoch 4/10
#   Train Acc: 0.9470 | Test Acc (Overall): 0.9265
#   Per Task: [0.9265, 0.0, 0.0, 0.0, 0.0]
# Epoch 5/10
#   Train Acc: 0.9575 | Test Acc (Overall): 0.9470
#   Per Task: [0.947, 0.0, 0.0, 0.0, 0.0]
# Epoch 6/10
#   Train Acc: 0.9672 | Test Acc (Overall): 0.9450
#   Per Task: [0.945, 0.0, 0.0, 0.0, 0.0]
# Epoch 7/10
#   Train Acc: 0.9734 | Test Acc (Overall): 0.9490
#   Per Task: [0.949, 0.0, 0.0, 0.0, 0.0]
# Epoch 8/10
#   Train Acc: 0.9816 | Test Acc (Overall): 0.9460
#   Per Task: [0.946, 0.0, 0.0, 0.0, 0.0]
# Epoch 9/10
#   Train Acc: 0.9858 | Test Acc (Overall): 0.9495
#   Per Task: [0.9495, 0.0, 0.0, 0.0, 0.0]
# Epoch 10/10
#   Train Acc: 0.9917 | Test Acc (Overall): 0.9475
#   Per Task: [0.9475, 0.0, 0.0, 0.0, 0.0]
#
# [Consolidating] Storing memories from Task 0...
#    [Buffer] Added 200 samples for Class 0
#    [Buffer] Added 200 samples for Class 1
#
# === Training on task 2/5 ===
# Epoch 1/10
# NREM Replay Epoch 1/5
# NREM Replay Epoch 2/5
# NREM Replay Epoch 3/5
# NREM Replay Epoch 4/5
# NREM Replay Epoch 5/5
#   Train Acc: 0.6130 | Test Acc (Overall): 0.3870
#   Per Task: [0.0, 0.774, 0.0, 0.0, 0.0]
# Epoch 2/10
# NREM Replay Epoch 1/5
# NREM Replay Epoch 2/5
# NREM Replay Epoch 3/5
# NREM Replay Epoch 4/5
# NREM Replay Epoch 5/5
#   Train Acc: 0.7895 | Test Acc (Overall): 0.3910
#   Per Task: [0.0, 0.782, 0.0, 0.0, 0.0]
# Epoch 3/10
# NREM Replay Epoch 1/5
# NREM Replay Epoch 2/5
# NREM Replay Epoch 3/5
# NREM Replay Epoch 4/5
# NREM Replay Epoch 5/5
#   Train Acc: 0.8167 | Test Acc (Overall): 0.4000
#   Per Task: [0.0, 0.8, 0.0, 0.0, 0.0]
# Epoch 4/10
# NREM Replay Epoch 1/5
# NREM Replay Epoch 2/5
# NREM Replay Epoch 3/5
# NREM Replay Epoch 4/5
# NREM Replay Epoch 5/5
#   Train Acc: 0.8398 | Test Acc (Overall): 0.3960
#   Per Task: [0.0, 0.792, 0.0, 0.0, 0.0]
# Epoch 5/10
# NREM Replay Epoch 1/5
# NREM Replay Epoch 2/5
# NREM Replay Epoch 3/5
# NREM Replay Epoch 4/5
# NREM Replay Epoch 5/5
#   Train Acc: 0.8544 | Test Acc (Overall): 0.4000
#   Per Task: [0.003, 0.797, 0.0, 0.0, 0.0]
# Epoch 6/10
# NREM Replay Epoch 1/5
# NREM Replay Epoch 2/5
# NREM Replay Epoch 3/5
# NREM Replay Epoch 4/5
# NREM Replay Epoch 5/5
#   Train Acc: 0.8768 | Test Acc (Overall): 0.4190
#   Per Task: [0.026, 0.812, 0.0, 0.0, 0.0]
# Epoch 7/10
# NREM Replay Epoch 1/5
# NREM Replay Epoch 2/5
# NREM Replay Epoch 3/5
# NREM Replay Epoch 4/5
# NREM Replay Epoch 5/5
#   Train Acc: 0.8790 | Test Acc (Overall): 0.4248
#   Per Task: [0.0275, 0.822, 0.0, 0.0, 0.0]
# Epoch 8/10
# NREM Replay Epoch 1/5
# NREM Replay Epoch 2/5
# NREM Replay Epoch 3/5
# NREM Replay Epoch 4/5
# NREM Replay Epoch 5/5
#   Train Acc: 0.8993 | Test Acc (Overall): 0.4198
#   Per Task: [0.0135, 0.826, 0.0, 0.0, 0.0]
# Epoch 9/10
# NREM Replay Epoch 1/5
# NREM Replay Epoch 2/5
# NREM Replay Epoch 3/5
# NREM Replay Epoch 4/5
# NREM Replay Epoch 5/5
#   Train Acc: 0.9070 | Test Acc (Overall): 0.4475
#   Per Task: [0.0795, 0.8155, 0.0, 0.0, 0.0]
# Epoch 10/10
# NREM Replay Epoch 1/5
# NREM Replay Epoch 2/5
# NREM Replay Epoch 3/5
# NREM Replay Epoch 4/5
# NREM Replay Epoch 5/5
#   Train Acc: 0.9186 | Test Acc (Overall): 0.4397
#   Per Task: [0.0955, 0.784, 0.0, 0.0, 0.0]
#
# [Consolidating] Storing memories from Task 1...
#    [Buffer] Added 200 samples for Class 2
#    [Buffer] Added 200 samples for Class 3
#
# === Training on task 3/5 ===
# Epoch 1/10
# NREM Replay Epoch 1/5
# NREM Replay Epoch 2/5
# NREM Replay Epoch 3/5
# NREM Replay Epoch 4/5
# NREM Replay Epoch 5/5
#   Train Acc: 0.5619 | Test Acc (Overall): 0.2068
#   Per Task: [0.0, 0.0, 0.6205, 0.0, 0.0]
# Epoch 2/10
# NREM Replay Epoch 1/5
# NREM Replay Epoch 2/5
# NREM Replay Epoch 3/5
# NREM Replay Epoch 4/5
# NREM Replay Epoch 5/5
#   Train Acc: 0.8189 | Test Acc (Overall): 0.2797
#   Per Task: [0.032, 0.008, 0.799, 0.0, 0.0]
# Epoch 3/10
# NREM Replay Epoch 1/5
# NREM Replay Epoch 2/5
# NREM Replay Epoch 3/5
# NREM Replay Epoch 4/5
# NREM Replay Epoch 5/5
#   Train Acc: 0.8657 | Test Acc (Overall): 0.2825
#   Per Task: [0.002, 0.002, 0.8435, 0.0, 0.0]
# Epoch 4/10
# NREM Replay Epoch 1/5
# NREM Replay Epoch 2/5
# NREM Replay Epoch 3/5
# NREM Replay Epoch 4/5
# NREM Replay Epoch 5/5
#   Train Acc: 0.8876 | Test Acc (Overall): 0.2943
#   Per Task: [0.0, 0.0005, 0.8825, 0.0, 0.0]
# Epoch 5/10
# NREM Replay Epoch 1/5
# NREM Replay Epoch 2/5
# NREM Replay Epoch 3/5
# NREM Replay Epoch 4/5
# NREM Replay Epoch 5/5
#   Train Acc: 0.9043 | Test Acc (Overall): 0.2930
#   Per Task: [0.0, 0.0, 0.879, 0.0, 0.0]
# Epoch 6/10
# NREM Replay Epoch 1/5
# NREM Replay Epoch 2/5
# NREM Replay Epoch 3/5
# NREM Replay Epoch 4/5
# NREM Replay Epoch 5/5
#   Train Acc: 0.9145 | Test Acc (Overall): 0.2937
#   Per Task: [0.0, 0.0, 0.881, 0.0, 0.0]
# Epoch 7/10
# NREM Replay Epoch 1/5
# NREM Replay Epoch 2/5
# NREM Replay Epoch 3/5
# NREM Replay Epoch 4/5
# NREM Replay Epoch 5/5
#   Train Acc: 0.9238 | Test Acc (Overall): 0.2927
#   Per Task: [0.0, 0.0, 0.878, 0.0, 0.0]
# Epoch 8/10
# NREM Replay Epoch 1/5
# NREM Replay Epoch 2/5
# NREM Replay Epoch 3/5
# NREM Replay Epoch 4/5
# NREM Replay Epoch 5/5
#   Train Acc: 0.9290 | Test Acc (Overall): 0.2965
#   Per Task: [0.0, 0.0, 0.8895, 0.0, 0.0]
# Epoch 9/10
# NREM Replay Epoch 1/5
# NREM Replay Epoch 2/5
# NREM Replay Epoch 3/5
# NREM Replay Epoch 4/5
# NREM Replay Epoch 5/5
#   Train Acc: 0.9403 | Test Acc (Overall): 0.2813
#   Per Task: [0.0, 0.0, 0.844, 0.0, 0.0]
# Epoch 10/10
# NREM Replay Epoch 1/5
# NREM Replay Epoch 2/5
# NREM Replay Epoch 3/5
# NREM Replay Epoch 4/5
# NREM Replay Epoch 5/5
#   Train Acc: 0.9469 | Test Acc (Overall): 0.2867
#   Per Task: [0.0, 0.0, 0.86, 0.0, 0.0]
#
# [Consolidating] Storing memories from Task 2...
#    [Buffer] Added 200 samples for Class 4
#    [Buffer] Added 200 samples for Class 5
#
# === Training on task 4/5 ===
# Epoch 1/10
# NREM Replay Epoch 1/5
# NREM Replay Epoch 2/5
# NREM Replay Epoch 3/5
# NREM Replay Epoch 4/5
# NREM Replay Epoch 5/5
#   Train Acc: 0.6595 | Test Acc (Overall): 0.1150
#   Per Task: [0.1645, 0.0, 0.0005, 0.295, 0.0]
# Epoch 2/10
# NREM Replay Epoch 1/5
# NREM Replay Epoch 2/5
# NREM Replay Epoch 3/5
# NREM Replay Epoch 4/5
# NREM Replay Epoch 5/5
#   Train Acc: 0.9400 | Test Acc (Overall): 0.2330
#   Per Task: [0.0, 0.0, 0.0, 0.932, 0.0]
# Epoch 3/10
# NREM Replay Epoch 1/5
# NREM Replay Epoch 2/5
# NREM Replay Epoch 3/5
# NREM Replay Epoch 4/5
# NREM Replay Epoch 5/5
#   Train Acc: 0.9616 | Test Acc (Overall): 0.2350
#   Per Task: [0.0, 0.0, 0.001, 0.939, 0.0]
# Epoch 4/10
# NREM Replay Epoch 1/5
# NREM Replay Epoch 2/5
# NREM Replay Epoch 3/5
# NREM Replay Epoch 4/5
# NREM Replay Epoch 5/5
#   Train Acc: 0.9680 | Test Acc (Overall): 0.2320
#   Per Task: [0.0, 0.0045, 0.0025, 0.921, 0.0]
# Epoch 5/10
# NREM Replay Epoch 1/5
# NREM Replay Epoch 2/5
# NREM Replay Epoch 3/5
# NREM Replay Epoch 4/5
# NREM Replay Epoch 5/5
#   Train Acc: 0.9773 | Test Acc (Overall): 0.2300
#   Per Task: [0.0, 0.0, 0.001, 0.919, 0.0]
# Epoch 6/10
# NREM Replay Epoch 1/5
# NREM Replay Epoch 2/5
# NREM Replay Epoch 3/5
# NREM Replay Epoch 4/5
# NREM Replay Epoch 5/5
#   Train Acc: 0.9790 | Test Acc (Overall): 0.2221
#   Per Task: [0.0, 0.0, 0.0005, 0.888, 0.0]
# Epoch 7/10
# NREM Replay Epoch 1/5
# NREM Replay Epoch 2/5
# NREM Replay Epoch 3/5
# NREM Replay Epoch 4/5
# NREM Replay Epoch 5/5
#   Train Acc: 0.9817 | Test Acc (Overall): 0.2216
#   Per Task: [0.0, 0.0, 0.0, 0.8865, 0.0]
# Epoch 8/10
# NREM Replay Epoch 1/5
# NREM Replay Epoch 2/5
# NREM Replay Epoch 3/5
# NREM Replay Epoch 4/5
# NREM Replay Epoch 5/5
#   Train Acc: 0.9872 | Test Acc (Overall): 0.2184
#   Per Task: [0.0, 0.0, 0.0, 0.8735, 0.0]
# Epoch 9/10
# NREM Replay Epoch 1/5
# NREM Replay Epoch 2/5
# NREM Replay Epoch 3/5
# NREM Replay Epoch 4/5
# NREM Replay Epoch 5/5
#   Train Acc: 0.9900 | Test Acc (Overall): 0.2240
#   Per Task: [0.0, 0.0, 0.0, 0.896, 0.0]
# Epoch 10/10
# NREM Replay Epoch 1/5
# NREM Replay Epoch 2/5
# NREM Replay Epoch 3/5
# NREM Replay Epoch 4/5
# NREM Replay Epoch 5/5
#   Train Acc: 0.9924 | Test Acc (Overall): 0.2230
#   Per Task: [0.0, 0.0, 0.0, 0.892, 0.0]
#
# [Consolidating] Storing memories from Task 3...
#    [Buffer] Added 200 samples for Class 6
#    [Buffer] Added 200 samples for Class 7
#
# === Training on task 5/5 ===
# Epoch 1/10
# NREM Replay Epoch 1/5
# NREM Replay Epoch 2/5
# NREM Replay Epoch 3/5
# NREM Replay Epoch 4/5
# NREM Replay Epoch 5/5
#   Train Acc: 0.5431 | Test Acc (Overall): 0.1203
#   Per Task: [0.0, 0.0, 0.0, 0.4965, 0.105]
# Epoch 2/10
# NREM Replay Epoch 1/5
# NREM Replay Epoch 2/5
# NREM Replay Epoch 3/5
# NREM Replay Epoch 4/5
# NREM Replay Epoch 5/5
#   Train Acc: 0.8712 | Test Acc (Overall): 0.1140
#   Per Task: [0.0, 0.0, 0.0, 0.0005, 0.5695]
# Epoch 3/10
# NREM Replay Epoch 1/5
# NREM Replay Epoch 2/5
# NREM Replay Epoch 3/5
# NREM Replay Epoch 4/5
# NREM Replay Epoch 5/5
#   Train Acc: 0.9083 | Test Acc (Overall): 0.1231
#   Per Task: [0.0, 0.0, 0.0, 0.0, 0.6155]
# Epoch 4/10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 downscaling_model_p50 = SynapticDownscalingModel()
# ----> 2 train_accuracies_p50, test_accuracies_p50, train_losses_p50, per_task_test_accuracies_p50 = train_model(downscaling_model_p50, train_dataset, test_dataset, nrem_replay=True, synaptic_downscaling=True, p=0.5)
#       3 plot_accuracies(train_accuracies_p50, test_accuracies_p50, epochs)
#
# File c:\Users\adity\OneDrive\Documents\college\4-1\proj\synaptic-downscaling-expt\model.py:188, in train_model(model, train_dataset, test_dataset, epochs_per_task, batch_size, learning_rate, p, synaptic_downscaling, pruning, nrem_replay)
#     186 images, labels = images.to(device), labels.to(device)
#     187 optimizer.zero_grad()
# --> 188 outputs = model(images)
#     189 loss = criterion(outputs, labels) * (1/(task+1))
#     190 loss.backward()
#
# File c:\Users\adity\OneDrive\Documents\college\4-1\proj\synaptic-downscaling-expt\env\lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\adity\OneDrive\Documents\college\4-1\proj\synaptic-downscaling-expt\env\lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\adity\OneDrive\Documents\college\4-1\proj\synaptic-downscaling-expt\model.py:52, in SynapticDownscalingModel.forward(self, x)
#      50 out = self.flatten(out)
#      51 out = self.fc1(out)
# ---> 52 out = self.relu3(out)
#      53 out = self.fc3(out)
#      54 return out
#
# File c:\Users\adity\OneDrive\Documents\college\4-1\proj\synaptic-downscaling-expt\env\lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\adity\OneDrive\Documents\college\4-1\proj\synaptic-downscaling-expt\env\lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\adity\OneDrive\Documents\college\4-1\proj\synaptic-downscaling-expt\env\lib\site-packages\torch\nn\modules\activation.py:144, in ReLU.forward(self, input)
#     140 def forward(self, input: Tensor) -> Tensor:
#     141     """
#     142     Runs the forward pass.
#     143     """
# --> 144     return F.relu(input, inplace=self.inplace)
#
# File c:\Users\adity\OneDrive\Documents\college\4-1\proj\synaptic-downscaling-expt\env\lib\site-packages\torch\nn\functional.py:1697, in relu(input, inplace)
#    1695     result = torch.relu_(input)
#    1696 else:
# -> 1697     result = torch.relu(input)
#    1698 return result
#
# KeyboardInterrupt:

# %%
downscaling_model_p75 = SynapticDownscalingModel()
train_accuracies_p75, test_accuracies_p75, train_losses_p75, per_task_test_accuracies_p75 = train_model(downscaling_model_p75, train_dataset, test_dataset, nrem_replay=True, synaptic_downscaling=True, p=0.75, epochs_per_task=5)
plot_accuracies(train_accuracies_p75, test_accuracies_p75, epochs, task_epochs)
# Out:
# === Training on task 1/5 ===
# Epoch 1/10
#   Train Acc: 0.8359 | Test Acc (Overall): 0.8730
#   Per Task: [0.873, 0.0, 0.0, 0.0, 0.0]
# Epoch 2/10
#   Train Acc: 0.9230 | Test Acc (Overall): 0.9305
#   Per Task: [0.9305, 0.0, 0.0, 0.0, 0.0]
# Epoch 3/10
#   Train Acc: 0.9397 | Test Acc (Overall): 0.9415
#   Per Task: [0.9415, 0.0, 0.0, 0.0, 0.0]
# Epoch 4/10
#   Train Acc: 0.9518 | Test Acc (Overall): 0.9335
#   Per Task: [0.9335, 0.0, 0.0, 0.0, 0.0]
# Epoch 5/10
#   Train Acc: 0.9603 | Test Acc (Overall): 0.9430
#   Per Task: [0.943, 0.0, 0.0, 0.0, 0.0]
# Epoch 6/10
#   Train Acc: 0.9668 | Test Acc (Overall): 0.9295
#   Per Task: [0.9295, 0.0, 0.0, 0.0, 0.0]
# Epoch 7/10
#   Train Acc: 0.9737 | Test Acc (Overall): 0.9510
#   Per Task: [0.951, 0.0, 0.0, 0.0, 0.0]
# Epoch 8/10
#   Train Acc: 0.9785 | Test Acc (Overall): 0.9415
#   Per Task: [0.9415, 0.0, 0.0, 0.0, 0.0]
# Epoch 9/10
#   Train Acc: 0.9830 | Test Acc (Overall): 0.9395
#   Per Task: [0.9395, 0.0, 0.0, 0.0, 0.0]
# Epoch 10/10
#   Train Acc: 0.9858 | Test Acc (Overall): 0.9445
#   Per Task: [0.9445, 0.0, 0.0, 0.0, 0.0]
#
# [Consolidating] Storing memories from Task 0...
#    [Buffer] Added 200 samples for Class 0
#    [Buffer] Added 200 samples for Class 1
#
# === Training on task 2/5 ===
# Epoch 1/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.6324 | Test Acc (Overall): 0.3867
#   Per Task: [0.0, 0.7735, 0.0, 0.0, 0.0]
# Epoch 2/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.8015 | Test Acc (Overall): 0.4002
#   Per Task: [0.0, 0.8005, 0.0, 0.0, 0.0]
# Epoch 3/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.8325 | Test Acc (Overall): 0.4095
#   Per Task: [0.0, 0.819, 0.0, 0.0, 0.0]
# Epoch 4/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.8549 | Test Acc (Overall): 0.4188
#   Per Task: [0.0, 0.8375, 0.0, 0.0, 0.0]
# Epoch 5/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.8814 | Test Acc (Overall): 0.4170
#   Per Task: [0.0, 0.834, 0.0, 0.0, 0.0]
# Epoch 6/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.8932 | Test Acc (Overall): 0.4110
#   Per Task: [0.0, 0.822, 0.0, 0.0, 0.0]
# Epoch 7/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.9078 | Test Acc (Overall): 0.4205
#   Per Task: [0.0, 0.841, 0.0, 0.0, 0.0]
# Epoch 8/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.9242 | Test Acc (Overall): 0.4085
#   Per Task: [0.0, 0.817, 0.0, 0.0, 0.0]
# Epoch 9/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.9378 | Test Acc (Overall): 0.4183
#   Per Task: [0.0, 0.8365, 0.0, 0.0, 0.0]
# Epoch 10/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.9508 | Test Acc (Overall): 0.4203
#   Per Task: [0.0, 0.8405, 0.0, 0.0, 0.0]
#
# [Consolidating] Storing memories from Task 1...
#    [Buffer] Added 200 samples for Class 2
#    [Buffer] Added 200 samples for Class 3
#
# === Training on task 3/5 ===
# Epoch 1/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.6102 | Test Acc (Overall): 0.2773
#   Per Task: [0.0, 0.0, 0.832, 0.0, 0.0]
# Epoch 2/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.8637 | Test Acc (Overall): 0.2823
#   Per Task: [0.0, 0.0, 0.847, 0.0, 0.0]
# Epoch 3/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.8939 | Test Acc (Overall): 0.2853
#   Per Task: [0.0, 0.0, 0.856, 0.0, 0.0]
# Epoch 4/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.9058 | Test Acc (Overall): 0.2968
#   Per Task: [0.0, 0.0, 0.8905, 0.0, 0.0]
# Epoch 5/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.9202 | Test Acc (Overall): 0.2995
#   Per Task: [0.0, 0.0, 0.8985, 0.0, 0.0]
# Epoch 6/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.9317 | Test Acc (Overall): 0.2973
#   Per Task: [0.0, 0.0, 0.892, 0.0, 0.0]
# Epoch 7/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.9402 | Test Acc (Overall): 0.2983
#   Per Task: [0.0, 0.0005, 0.8945, 0.0, 0.0]
# Epoch 8/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.9496 | Test Acc (Overall): 0.3008
#   Per Task: [0.0, 0.0, 0.9025, 0.0, 0.0]
# Epoch 9/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.9607 | Test Acc (Overall): 0.3028
#   Per Task: [0.0, 0.0, 0.9085, 0.0, 0.0]
# Epoch 10/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.9661 | Test Acc (Overall): 0.2975
#   Per Task: [0.0, 0.0, 0.8925, 0.0, 0.0]
#
# [Consolidating] Storing memories from Task 2...
#    [Buffer] Added 200 samples for Class 4
#    [Buffer] Added 200 samples for Class 5
#
# === Training on task 4/5 ===
# Epoch 1/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.6158 | Test Acc (Overall): 0.2241
#   Per Task: [0.0, 0.0, 0.0, 0.8965, 0.0]
# Epoch 2/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.9188 | Test Acc (Overall): 0.2351
#   Per Task: [0.0, 0.0, 0.0, 0.9405, 0.0]
# Epoch 3/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.9513 | Test Acc (Overall): 0.2389
#   Per Task: [0.0, 0.0, 0.0, 0.9555, 0.0]
# Epoch 4/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.9608 | Test Acc (Overall): 0.2401
#   Per Task: [0.0, 0.0015, 0.0, 0.959, 0.0]
# Epoch 5/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.9691 | Test Acc (Overall): 0.2371
#   Per Task: [0.0, 0.0, 0.0, 0.9485, 0.0]
# Epoch 6/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.9720 | Test Acc (Overall): 0.2389
#   Per Task: [0.0, 0.0, 0.0, 0.9555, 0.0]
# Epoch 7/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.9763 | Test Acc (Overall): 0.2419
#   Per Task: [0.0, 0.0, 0.0, 0.9675, 0.0]
# Epoch 8/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.9788 | Test Acc (Overall): 0.2416
#   Per Task: [0.0, 0.0, 0.0, 0.9665, 0.0]
# Epoch 9/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.9816 | Test Acc (Overall): 0.2415
#   Per Task: [0.0, 0.0, 0.0, 0.966, 0.0]
# Epoch 10/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.9879 | Test Acc (Overall): 0.2402
#   Per Task: [0.0, 0.0005, 0.0, 0.9605, 0.0]
#
# [Consolidating] Storing memories from Task 3...
#    [Buffer] Added 200 samples for Class 6
#    [Buffer] Added 200 samples for Class 7
#
# === Training on task 5/5 ===
# Epoch 1/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.6767 | Test Acc (Overall): 0.1716
#   Per Task: [0.0, 0.0, 0.0, 0.0, 0.858]
# Epoch 2/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.9275 | Test Acc (Overall): 0.1772
#   Per Task: [0.0, 0.0, 0.0, 0.0, 0.886]
# Epoch 3/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.9500 | Test Acc (Overall): 0.1671
#   Per Task: [0.0, 0.0, 0.0, 0.0, 0.8355]
# Epoch 4/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.9650 | Test Acc (Overall): 0.1679
#   Per Task: [0.0, 0.0, 0.0, 0.0, 0.8395]
# Epoch 5/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.9706 | Test Acc (Overall): 0.1787
#   Per Task: [0.0, 0.0, 0.0, 0.0, 0.8935]
# Epoch 6/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.9835 | Test Acc (Overall): 0.1804
#   Per Task: [0.0, 0.0, 0.0, 0.0, 0.902]
# Epoch 7/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.9897 | Test Acc (Overall): 0.1789
#   Per Task: [0.0, 0.0, 0.0, 0.0, 0.8945]
# Epoch 8/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.9934 | Test Acc (Overall): 0.1798
#   Per Task: [0.0, 0.0, 0.0, 0.0, 0.899]
# Epoch 9/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.9970 | Test Acc (Overall): 0.1815
#   Per Task: [0.0, 0.0, 0.0005, 0.0, 0.907]
# Epoch 10/10
# NREM Replay Epoch 1/1
#   Train Acc: 0.9963 | Test Acc (Overall): 0.1809
#   Per Task: [0.0, 0.0, 0.0, 0.0, 0.9045]
#
# [Consolidating] Storing memories from Task 4...
#    [Buffer] Added 200 samples for Class 8
#    [Buffer] Added 200 samples for Class 9

# %%
num_tasks = 5
colors = plt.cm.get_cmap('tab10', num_tasks)
task_labels = [f"Task {t}" for t in range(num_tasks)]

fig, axes = plt.subplots(1, 4, sharey=True)

model_tests = [per_task_test_accuracies,per_task_test_accuracies_p25, per_task_test_accuracies_p50, per_task_test_accuracies_p75]

for i in range(len(model_tests)):
    ax=axes[i]
    y_stack=[]
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_28832\1363256411.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap('tab10', num_tasks)
